# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as scipy

# %%
grain_size = pd.read_csv('Oleson_grain_size_mesure_mastet.csv')
grain_size
# Out:
#      Sample  Measurement  Width (µm)  Height (µm)  Major Axis (µm)  \
# 0    71923B            1       29.87        26.37            29.87
# 1    71923B            2       46.62        39.46            46.62
# 2    71923B            3       25.62        25.61            25.62
# 3    71923B            4       19.43        17.61            19.43
# 4    71923B            5       26.42        26.42            26.42
# ..      ...          ...         ...          ...              ...
# 742  90423A           86       27.98        27.97            27.98
# 743  90423A           87      100.58        50.66           100.58
# 744  90423A           88      106.70        36.94           106.70
# 745  90423A           89      169.68        94.50           169.68
# 746  90423A           90       36.62        23.07            36.62
#
#      Minor Axis (µm)  Angle (°)
# 0              26.37      52.39
# 1              39.46      41.54
# 2              25.61      30.41
# ...

# %%
grain_size['Sample'].unique()
# Out:
# array(['71923B', '71923A', '80823A', 'prc', 'j2', 'lpns', 'lpsc',
#        '83123A', '90423A'], dtype=object)

# %%
Omega71923B = grain_size[grain_size['Sample'] == '71923B']
Omega71923A = grain_size[grain_size['Sample']== '71923A']
BMTC80823A  = grain_size[grain_size['Sample'] == '80823A']
prc = grain_size[grain_size['Sample'] == 'prc']
j2 = grain_size[grain_size['Sample'] == 'j2']
lpns = grain_size[grain_size['Sample']== 'lpns']
lpsc = grain_size[grain_size['Sample'] == 'lpsc']
onon83123A = grain_size[grain_size['Sample']== '83123A']
Bss90423A = grain_size[grain_size['Sample']== '90423A']


Omega71923A_mean = Omega71923A['Height (µm)'].mean()
Omega71923B_mean = Omega71923B['Height (µm)'].mean()
BMTC80823A_mean = BMTC80823A['Height (µm)'].mean()
prc_mean = prc['Height (µm)'].mean()
j2_mean = j2['Height (µm)'].mean()
lpns_mean = lpns['Height (µm)'].mean()
lpsc_mean = lpsc['Height (µm)'].mean()
onon83123A_mean =  onon83123A['Height (µm)'].mean()
Bss90423A_mean = Bss90423A['Height (µm)'].mean()


Omega71923A_max = Omega71923A['Height (µm)'].max()
Omega71923B_max = Omega71923B['Height (µm)'].max()
BMTC80823A_max = BMTC80823A['Height (µm)'].max()
prc_max = prc['Height (µm)'].max()
j2_max = j2['Height (µm)'].max()
lpns_max = lpns['Height (µm)'].max()
lpsc_max = lpsc['Height (µm)'].max()
onon83123A_max =  onon83123A['Height (µm)'].max()
Bss90423A_max = Bss90423A['Height (µm)'].max()


Omega71923A_min = Omega71923A['Height (µm)'].min()
Omega71923B_min = Omega71923B['Height (µm)'].min()
BMTC80823A_min = BMTC80823A['Height (µm)'].min()
prc_min = prc['Height (µm)'].min()
j2_min= j2['Height (µm)'].min()
lpns_min = lpns['Height (µm)'].min()
lpsc_min = lpsc['Height (µm)'].min()
onon83123A_min =  onon83123A['Height (µm)'].min()
Bss90423A_min = Bss90423A['Height (µm)'].min()

Omega71923A_median = Omega71923A['Height (µm)'].median()
Omega71923B_median = Omega71923B['Height (µm)'].median()
BMTC80823A_median = BMTC80823A['Height (µm)'].median()
prc_median = prc['Height (µm)'].median()
j2_median = j2['Height (µm)'].median()
lpns_median = lpns['Height (µm)'].median()
lpsc_median = lpsc['Height (µm)'].median()
onon83123A_median = onon83123A['Height (µm)'].median()
Bss90423A_median = Bss90423A['Height (µm)'].median() 

print('Omega 71921A', "mean, median,max,min:", Omega71923A_mean, Omega71923A_median, Omega71923A_max, Omega71923A_min)
print('Omega 71921B', "mean, median, max,min:", Omega71923B_mean, Omega71923B_median, Omega71923B_max, Omega71923B_min)
print('BM-TC', "mean,median, max,min:", BMTC80823A_mean, BMTC80823A_median, BMTC80823A_max, BMTC80823A_min)
print('prc', "mean, median, max,min:", prc_mean, prc_median, prc_max, prc_min)
print('j2', "mean,median, max,min:", j2_mean, j2_median, j2_max, j2_min)
print('lpns', "mean, median, max,min:", lpns_mean, lpns_median, lpns_max, lpns_min)
print('lpsc', 'mean, median, max, min', lpsc_mean, lpsc_median, lpsc_max, lpsc_min)
print('Onondaga', "mean, median, max,min:", onon83123A_mean, onon83123A_median, onon83123A_max, onon83123A_min)
print('BSS', "mean, median, max,min:", Bss90423A_mean, Bss90423A_median, Bss90423A_max, Bss90423A_min)
# Out:
# Omega 71921A mean, median,max,min: 423.4234234234234 420.0 780.0 150.0
# Omega 71921B mean, median, max,min: 20.51816326530612 19.145000000000003 39.46 7.99
# BM-TC mean,median, max,min: 44.210294117647045 42.67 108.14 17.83
# prc mean, median, max,min: 19.441750000000003 18.61 33.0 10.13
# j2 mean,median, max,min: 127.08923076923075 121.09 362.92 55.84
# lpns mean, median, max,min: 174.36390408058818 138.68173524999997 726.0023442 49.39270038
# lpsc mean, median, max, min 114.5354761904762 112.66499999999999 191.65 42.36
# Onondaga mean, median, max,min: 94.71977528089887 78.86 284.09 23.02
# BSS mean, median, max,min: 47.855222222222224 32.769999999999996 299.64 12.47

# %%
Omega71923A_IQR = scipy.iqr(Omega71923A['Height (µm)'])
Omega71923B_IQR = scipy.iqr(Omega71923B['Height (µm)'])
BMTC80823A_IQR = scipy.iqr(BMTC80823A['Height (µm)'])
prc_IQR = scipy.iqr(prc['Height (µm)'])
j2_IQR = scipy.iqr(j2['Height (µm)'])
lpns_IQR = scipy.iqr(lpns['Height (µm)'])
lpsc_IQR = scipy.iqr(lpsc['Height (µm)'])
onon83123A_IQR = scipy.iqr(onon83123A['Height (µm)'])
Bss90423A_IQR = scipy.iqr(Bss90423A['Height (µm)']) 

print('Omega 71921A', "IQR:", Omega71923A_IQR)
print('Omega 71921B', "IQR:", Omega71923B_IQR)
print('BM-TC', "IQR:", BMTC80823A_IQR)
print('prc', "IQR:", prc_IQR)
print('j2', "IQR:", j2_IQR)
print('lpns', "IQR:", lpns_IQR)
print('lpsc', "IQR:", lpsc_IQR)
print('Onondaga', "IQR:", onon83123A_IQR)
print('BSS', "IQR:", Bss90423A_IQR)
# Out:
# Omega 71921A IQR: 180.0
# Omega 71921B IQR: 9.3625
# BM-TC IQR: 16.295
# prc IQR: 7.897499999999999
# j2 IQR: 44.22000000000001
# lpns IQR: 90.05118157250001
# lpsc IQR: 37.95
# Onondaga IQR: 48.800000000000004
# BSS IQR: 21.449999999999996

# %%
BMTC80823A
# Out:
#      Sample  Measurement  Width (µm)  Height (µm)  Major Axis (µm)  \
# 209  80823A            1       58.00        46.39            58.00
# 210  80823A            2       37.85        37.85            37.85
# 211  80823A            3       53.73        53.73            53.73
# 212  80823A            4       40.78        32.66            40.78
# 213  80823A            5       40.40        34.38            40.40
# ..      ...          ...         ...          ...              ...
# 306  80823A           98       68.20        68.19            68.20
# 307  80823A           99       62.18        53.44            62.18
# 308  80823A          100       44.21        37.38            44.21
# 309  80823A          101       41.75        32.92            41.75
# 310  80823A          102       44.86        31.31            44.86
#
#      Minor Axis (µm)  Angle (°)
# 209            46.39     -27.09
# 210            37.85     -54.29
# 211            53.73     -97.19
# ...

# %% [markdown]
# ### Omega Limestone - 71923A

# %%
Omega71923A_mean = Omega71923A['Height (µm)'].mean()
Omega71923B_mean = Omega71923B['Height (µm)'].mean()
BMTC80823A_mean = BMTC80823A['Height (µm)'].mean()

Omega71923A_mean
# Out:
# np.float64(423.4234234234234)

# %%
fig, ax = plt.subplots()
sns.histplot(x= Omega71923A['Height (µm)'], color= 'lightgray')
plt.xlabel('Grain Size ($\mu m$)')
plt.plot([Omega71923A_mean, Omega71923A_mean], [0, 23], color = 'black', linewidth = 2.0)

#plt.savefig('OmegaLS_grain_size.png', dpi = 300)
#plt.show()

# %% [markdown]
# ### Omega Dolomite 71923B

# %%
OMe

# %%
fig, ax = plt.subplots()
sns.histplot(x = Omega71923B['height'], color= 'lightgray')
plt.xlabel('Grain Size ($\mu m$)')
plt.plot([Omega71923B_mean, Omega71923B_mean], [0, 27], color = 'black', linewidth = 2.0)

#plt.savefig('OmegaDolo_grain_size.png', dpi = 300)
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'height'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 fig, ax = plt.subplots()
# ...

# %% [markdown]
# ### Bad Medicine - Tres Charros - 80823A

# %%
fig, ax = plt.subplots()
sns.histplot(x = BMTC80823A['height'], color= 'lightgray')
plt.xlabel('Grain Size ($\mu m$)')
plt.plot([BMTC80823A_mean,BMTC80823A_mean], [0, 25], color = 'black', linewidth = 2.0)

#plt.savefig('BMTC_grain_size.png', dpi = 300)
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'height'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 fig, ax = plt.subplots()
# ...

# %%
fig, axes =plt.subplots(3,3, figsize =(9.75, 9.75))

#Omega Limestone
sns.histplot(Omega71923A, x = Omega71923A['Height (µm)'], bins = 10, color = 'gray', alpha = 0.5, ax = axes[0,0])
axes[0,0].set_ylabel('Frequency')
axes[0,0].set_xlabel('')
axes[0,0].set_ylim(0,65)


#Omega dolostone
sns.histplot(Omega71923B, x = Omega71923B['Height (µm)'], bins = 10, color= 'black', alpha = 0.5, ax = axes[0,1])
axes[0,1].set_xlabel('')
axes[0,1].set_ylabel('')
axes[0,1].set_ylim(0,65)


#Bad Medicine
sns.histplot(BMTC80823A, x = BMTC80823A['Height (µm)'], bins = 10, color = 'black', alpha = 0.5, ax = axes [0,2])
axes[0,2].set_xlabel('')
axes[0,2].set_ylabel('')
axes[0,2].set_ylim(0,65)


#Parks Ranch
sns.histplot(prc, x = prc['Height (µm)'], bins = 10, color = 'gray', alpha  = 0.5, ax = axes[1,0])
axes[1,0].set_ylabel('Frequency')
axes[1,0].set_xlabel('')
axes[1,0].set_ylim(0,65)

#J2
sns.histplot(j2, x = j2['Height (µm)'], bins = 10, color = 'black', alpha = 0.5, ax = axes[1, 1])
axes[1,1].set_xlabel('')
axes[1,1].set_ylabel('')
axes[1,1].set_ylim(0,65)


#Onondaga
sns.histplot(onon83123A, x = onon83123A['Height (µm)'], bins = 10, color = 'black', alpha = 0.5, ax = axes[1,2])
axes[1,2].set_xlabel('')
axes[1,2].set_ylabel('')
axes[1,2].set_ylim(0,65)

#SH - no scallops
sns.histplot(lpns, x = lpns['Height (µm)'], bins = 10, color = 'black', alpha = 0.5, ax = axes[2,0])
axes[2,0].set_ylabel('Frequency')
axes[2,0].set_xlabel('Intermediate Length ($\mu m$)')
axes[2,0].set_ylim(0,65)

#SH - Scalloped
sns.histplot(lpsc, x= lpsc['Height (µm)'], bins = 10, color= 'gray', alpha = 0.5, ax = axes[2,1])
axes[2,1].set_ylabel('')
axes[2,1].set_xlabel('Intermediate Length ($\mu m$)')
axes[2,1].set_ylim(0,65)

#Boy Scout Springs
sns.histplot(Bss90423A, x = Bss90423A['Height (µm)'], bins = 10, color= 'gray', alpha = 0.5, ax = axes[2,2])
axes[2,2].set_ylabel('')
axes[2,2].set_xlabel('Intermediate Length ($\mu m$)')
axes[2,2].set_ylim(0,65)
# Out:
# <>:46: SyntaxWarning: invalid escape sequence '\m'
# <>:52: SyntaxWarning: invalid escape sequence '\m'
# <>:58: SyntaxWarning: invalid escape sequence '\m'
# <>:46: SyntaxWarning: invalid escape sequence '\m'
# <>:52: SyntaxWarning: invalid escape sequence '\m'
# <>:58: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_275255/2620966567.py:46: SyntaxWarning: invalid escape sequence '\m'
#   axes[2,0].set_xlabel('Intermediate Length ($\mu m$)')
# /tmp/ipykernel_275255/2620966567.py:52: SyntaxWarning: invalid escape sequence '\m'
#   axes[2,1].set_xlabel('Intermediate Length ($\mu m$)')
# /tmp/ipykernel_275255/2620966567.py:58: SyntaxWarning: invalid escape sequence '\m'
#   axes[2,2].set_xlabel('Intermediate Length ($\mu m$)')
# (0.0, 65.0)

# %%
fig, axes =plt.subplots(3,1, figsize =(9.75, 9.75))

#Parks Ranch
sns.histplot(prc, x = prc['Height (µm)'], bins = 10, color = 'gray', alpha  = 0.5, ax = axes[0])
axes[0].plot([prc_mean, prc_mean], [0,12], linewidth = 2, color = 'dodgerblue', label = 'Mean size ')
axes[0].plot([prc_median, prc_median], [0,12], linewidth = 2, color = 'gold', label = 'Median size')
axes[0].set_ylabel('Frequency', fontsize = 14)
axes[0].set_xlabel('')
axes[0].set_ylim(0,35)
axes[0].set_xlim(0,110)
axes[0].text(80, 31, 'Parks Ranch Cave', fontsize = 14)

sns.histplot(Omega71923B, x = Omega71923B['Height (µm)'], bins = 10, color= 'black', alpha = 0.5, ax = axes[1])
axes[1].plot([Omega71923B_mean, Omega71923B_mean], [0,26], linewidth = 2, color ='dodgerblue', label = 'mean size')
axes[1].plot([Omega71923B_median, Omega71923B_median], [0,26], linewidth = 2, color ='gold', label = 'median size')
axes[1].set_xlabel('')
axes[1].set_ylabel('Frequency',fontsize = 14)
axes[1].set_ylim(0,35)
axes[1].set_xlim(0,110)
axes[1].text(75, 31, 'Omega Cave - 71923B', fontsize = 14)

sns.histplot(BMTC80823A, x = BMTC80823A['Height (µm)'], bins = 10, color = 'black', alpha = 0.5, ax = axes [2])
axes[2].plot([BMTC80823A_mean, BMTC80823A_mean], [0,34], linewidth = 2, color = 'dodgerblue', label = 'Mean size')
axes[2].plot([BMTC80823A_median, BMTC80823A_median], [0,34], linewidth = 2, color = 'gold', label = 'Median size')
axes[2].set_xlabel('Intermediate Length ($\mu m$)', fontsize = 14)
axes[2].set_ylabel('Frequency',fontsize = 14)
axes[2].set_ylim(0,35)
axes[2].set_xlim(0,110)
axes[2].text(72, 31, 'Bad Medicine-Tres Charros', fontsize = 14)
plt.legend(loc = 'right', bbox_to_anchor = (0.2, -0.3))
plt.savefig('allochem_sizes_plate_1.png', dpi =600)

plt.show()

# %%
fig, axes =plt.subplots(4,1, figsize =(9.75, 9.75))

#J2
sns.histplot(j2, x = j2['Height (µm)'], bins = 10, color = 'black', alpha = 0.5, ax = axes[0])
axes[0].set_xlabel('')
axes[0].plot([j2_mean, j2_mean], [0,22], linewidth = 2, color = 'dodgerblue', label = 'mean size')
axes[0].plot([j2_median, j2_median], [0,22], linewidth = 2, color = 'gold', label = 'median size')
axes[0].set_ylabel('Frequency', fontsize = 14)
axes[0].set_ylim(0,65)
axes[0].set_xlim(0,400)
axes[0].text(325, 55, 'Sistema J2', fontsize = 14)

#Onondaga
sns.histplot(onon83123A, x = onon83123A['Height (µm)'], bins = 10, color = 'black', alpha = 0.5, ax = axes[1])
axes[1].set_xlabel('')
axes[1].plot([onon83123A_mean, onon83123A_mean], [0,32], linewidth = 2, color = 'dodgerblue', label = 'mean size')
axes[1].plot([onon83123A_median, onon83123A_median], [0,32], linewidth = 2, color = 'gold', label = 'Median size')
axes[1].set_ylabel('Frequency', fontsize = 14)
axes[1].set_ylim(0,65)
axes[1].set_xlim(0,400)
axes[1].text(325, 55, 'Onondaga', fontsize = 14)

#Boy Scout Springs
sns.histplot(Bss90423A, x = Bss90423A['Height (µm)'], bins = 10, color= 'gray', alpha = 0.5, ax = axes[2])
axes[2].plot([Bss90423A_mean, Bss90423A_mean], [0,60], linewidth = 2, color = 'dodgerblue', label = 'mean size')
axes[2].plot([Bss90423A_median, Bss90423A_median], [0,60], linewidth = 2, color = 'gold', label = 'Median size')
axes[2].set_ylabel('Frequency', fontsize = 14)
axes[2].set_xlabel('')
axes[2].set_ylim(0,65)
axes[2].set_xlim(0,400)
axes[2].text(270, 55, 'Boy Scout Springs Cave', fontsize = 14)

#SH - Scalloped
sns.histplot(lpsc, x= lpsc['Height (µm)'], bins = 10, color= 'gray', alpha = 0.5, ax = axes[3])
axes[3].plot([lpsc_mean, lpsc_mean], [0,20], linewidth = 2, color = 'dodgerblue', label = 'Mean size')
axes[3].plot([lpsc_median, lpsc_median], [0,20], linewidth = 2, color = 'gold', label = 'Median size')
axes[3].set_ylabel('Frequency', fontsize = 14)
axes[3].set_xlabel('Intermediate Length ($\mu m$)', fontsize = 14)
axes[3].set_ylim(0,65)
axes[3].set_xlim(0,400)
axes[3].text(270, 45, '$ Sch \ddot{o} nberg$ \n $-H \ddot{o}hlensystem$ - LPSC', fontsize = 14)
plt.legend(loc = 'right', bbox_to_anchor = (0.2, -0.3))

plt.savefig('allochem_sizes_plate_2.png', dpi =600)

plt.show()
# Out:
# <>:38: SyntaxWarning: invalid escape sequence '\m'
# <>:41: SyntaxWarning: invalid escape sequence '\d'
# <>:38: SyntaxWarning: invalid escape sequence '\m'
# <>:41: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_275255/2228511236.py:38: SyntaxWarning: invalid escape sequence '\m'
#   axes[3].set_xlabel('Intermediate Length ($\mu m$)', fontsize = 14)
# /tmp/ipykernel_275255/2228511236.py:41: SyntaxWarning: invalid escape sequence '\d'
#   axes[3].text(270, 45, '$ Sch \ddot{o} nberg$ \n $-H \ddot{o}hlensystem$ - LPSC', fontsize = 14)

# %%
fig, axes =plt.subplots(2,1, figsize =(9.75, 6.75))

#SH - no scallops
sns.histplot(lpns, x = lpns['Height (µm)'], bins = 10, color = 'black', alpha = 0.5, ax = axes[0])
axes[0].plot([lpns_mean, lpns_mean], [0,28], linewidth = 2, color = 'dodgerblue', label = 'mean size')
axes[0].plot([lpns_median, lpns_median], [0,28], linewidth = 2, color = 'gold', label = 'mean size')
axes[0].set_ylabel('Frequency', fontsize = 14)
axes[0].set_xlabel('')
axes[0].set_ylim(0,40)
axes[0].set_xlim(0,800)
axes[0].text(550,30, '$ Sch \ddot{o} nberg$ \n $-H \ddot{o}hlensystem$ - LPNS', fontsize = 14)

#Omega Limestone
sns.histplot(Omega71923A, x = Omega71923A['Height (µm)'], bins = 10, color = 'gray', alpha = 0.5, ax = axes[1])
axes[1].plot([Omega71923A_mean, Omega71923A_mean], [0,22], linewidth = 2, color = 'dodgerblue', label = 'Mean Size')
axes[1].plot([Omega71923A_median, Omega71923A_median], [0,22], linewidth = 2, color = 'yellow', label = 'Median Size')
axes[1].set_ylabel('Frequency', fontsize = 14)
axes[1].set_xlabel('')
axes[1].set_ylim(0,40)
axes[1].set_xlim(0,800)
axes[1].set_xlabel('Intermediate Length ($\mu m$)', fontsize = 14)
axes[1].text(550,35, 'Omega Cave - 71923A', fontsize = 14)

plt.legend(loc = 'right', bbox_to_anchor = (0.2, -0.3))
plt.tight_layout()
plt.savefig('allochem_sizes_plate_3.png', dpi =600)

plt.show()

# %%
violin_data = pd.read_csv('Oleson_grain_size_forViolin.csv')
violin_data['Sample'].unique()
# Out:
# array(['71923B', '71923A', '80823A', '111123A', 'J2', 'LPSC', '83123A',
#        '90423A', 'LPNS'], dtype=object)

# %%
violinplot_pallete = {"Scalloped": "lightgray", "Non-scalloped": "dimgray"}

# %%
fig, ax = plt.subplots()
sns.violinplot(violin_data, y = 'Height', x = 'Sample', 
               ax= ax, density_norm='width',hue= 'scalloped?',
               palette= violinplot_pallete, dodge=False, bw_adjust=0.75, cut=0.5,
               order=['71923A', '71923B', 'LPSC', 'LPNS', 'J2', '80823A', '111123A', '83123A', '90423A' ])
plt.xticks(rotation = 45)
ax.set_xlabel('')
ax.set_ylabel(r'Intermediate Length ($\mu$m)')
plt.legend(title = '')
ax.set_yscale('log')
plt.tight_layout()
plt.savefig('grain_size_violin_plots.png', dpi =600, bbox_inches = 'tight' )
plt.show()

# %%
# Fix for KDE bleeding below zero on a log axis:
# Compute a log10-transformed copy of Height, let seaborn estimate the KDE
# in that space (no negative bleed possible), then relabel the y-axis ticks
# to look like a proper log axis.

import matplotlib.ticker as ticker

order = ['71923A', '71923B', 'LPSC', 'LPNS', 'J2', '80823A', '111123A', '83123A', '90423A']

violin_data_log = violin_data.copy()
violin_data_log['log_Height'] = np.log10(violin_data_log['Height'].clip(lower=1e-9))

fig, ax = plt.subplots(figsize=(6, 4))

sns.violinplot(
    violin_data_log, y='log_Height', x='Sample',
    ax=ax, density_norm='width', hue='scalloped?',
    palette=violinplot_pallete, dodge=False, bw_adjust=0.75, cut=2,
    order=order
)

# --- Proper log-axis tick appearance ---
# Major ticks at each power of 10
decades = [1, 2, 3, 4]   # 10^1 to 10^4 µm
major_ticks = decades     # positions in log10 space
major_labels = [f'$10^{d}$' for d in decades]

# Minor ticks at 2–9 × each decade
minor_ticks = [np.log10(m * 10**d) for d in [0, 1, 2, 3] for m in range(2, 10)]

ax.set_yticks(major_ticks)
ax.set_yticklabels(major_labels)
ax.set_yticks(minor_ticks, minor=True)
ax.yaxis.set_tick_params(which='minor', length=3)
plt.tick_params(axis = 'both', labelsize=10) 
# ax.grid(axis='y', which='major', linestyle='--', linewidth=0.5, alpha=0.5)
# ax.grid(axis='y', which='minor', linestyle=':', linewidth=0.3, alpha=0.3)

plt.xticks(rotation=45, ha='center')
ax.set_xlabel('')
ax.set_ylabel(r'Intermediate Length ($\mu$m)')
plt.legend(title='')
plt.tight_layout()
plt.savefig('grain_size_violin_plots_logkde.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
LPNS_violin = violin_data[violin_data['Sample'] == 'LPNS']
LPSC_violin = violin_data[violin_data['Sample']== 'LPSC']
LPSC_violin
# Out:
#     Sample  Height scalloped?
# 416   LPSC  122.24  Scalloped
# 417   LPSC  104.02  Scalloped
# 418   LPSC  127.63  Scalloped
# 419   LPSC  113.17  Scalloped
# 420   LPSC  191.65  Scalloped
# ..     ...     ...        ...
# 495   LPSC   69.92  Scalloped
# 496   LPSC  174.30  Scalloped
# 497   LPSC   67.87  Scalloped
# 498   LPSC   80.25  Scalloped
# 499   LPSC   98.79  Scalloped
#
# [84 rows x 3 columns]

# %%
fig, ax = plt.subplots()
sns.violinplot(data=LPNS_violin, y = 'Height', x= 'Sample')
ax.set_yscale('log')
ax.set_ylim(1,10000)
# Out:
# (1, 10000)

# %%
fig, ax = plt.subplots()
sns.violinplot(violin_data, y = 'Height', x = 'Sample', ax= ax, hue= 'scalloped', palette= violinplot_pallete, dodge=False, order= [""])
plt.xticks(rotation = 45)
ax.set_xlabel('')
ax.set_ylabel('Intermediate Length ($\mu$m)')
plt.legend(title = '')
ax.set_yscale('log')
plt.tight_layout()
#plt.savefig('grain_size_violin_plots.png', dpi =600, bbox_inches = 'tight' )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 fig, ax = plt.subplots()
# ----> 2 sns.violinplot(violin_data, y = 'Height', x = 'Sample', ax= ax, hue= 'scalloped', palette= violinplot_pallete, dodge=False, order= [""])
#       3 plt.xticks(rotation = 45)
#       4 ax.set_xlabel('')
#
# File c:\Users\eoles\anaconda3\Lib\site-packages\seaborn\categorical.py:2305, in violinplot(data, x, y, hue, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2297 def violinplot(
#    2298     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2299     bw="scott", cut=2, scale="area", scale_hue=True, gridsize=100,
#    (...)
#    2302     ax=None, **kwargs,
#    2303 ):
# -> 2305     plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
fig, ax = plt.subplots()
sns.kdeplot(LPSC_violin, x = 'Height', ax = ax, color= 'black', fill= True, alpha = 0.7, label = "Scalloped (LPSC)")
sns.kdeplot(LPNS_violin, x = 'Height', ax = ax,color = 'gray', fill= True, alpha = 0.7, label = "Non-scalloped (LPNS)")
ax.set_xlim(0,3000)
ax.set_xlabel('Grain Size ($\mu m$)')
ax.legend()
plt.savefig('LPSC-LPNS-grain-size-kde.png', dpi = 600)
plt.show()

# %%
data = LPSC_violin
data2 = LPNS_violin
combined_data = pd.concat([data, data2])

# Create the violin plot
plt.figure(figsize=(8, 10))
sns.violinplot(x='Height', y='Sample',data=combined_data, split=True, orient='h', hue= 'Sample')

# Customize the plot
plt.title('Vertically Oriented Violin Plots')
plt.xlabel('Values')
plt.ylabel('Group')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Sample data
data = pd.DataFrame({
    'Category': ['A']*100 + ['B']*100,
    'Values': np.concatenate([np.random.normal(0, 1, 100), np.random.normal(1, 1.5, 100)]),
    'Group': ['First']*200
})


# Combine the datasets
combined_data = pd.concat([data, data2])

# Create the violin plot
plt.figure(figsize=(8, 10))
sns.violinplot(x='Values', y='Group', hue='Category', data=combined_data, split=True, orient='h')

# Customize the plot
plt.title('Vertically Oriented Violin Plots')
plt.xlabel('Values')
plt.ylabel('Group')

# Show the plot
plt.show()

# %%
# Add a column to distinguish the datasets
LPNS_violin['Dataset'] = 'LPNS'
LPSC_violin['Dataset'] = 'LPSC'

# Combine the datasets
combined_data = pd.concat([LPNS_violin, LPSC_violin])

# Create the violin plot with minimal gap by controlling the width
plt.figure(figsize=(3, 4))
sns.violinplot(x='Height', y='Sample', data=combined_data, orient='h', hue='Dataset', split=True, palette='Greys', inner=None)

# Customize the plot
plt.xlabel('Grain Size ($\mu m$)')
plt.ylabel('')
plt.yticks([],[])

# Adjust the layout to minimize gaps
#plt.legend(title ='', loc = 'lower right')
plt.legend('')

# Show the plot
plt.savefig('lpns-lpsc-kdes-for-figure.png', dpi=600)
plt.show()
# Out:
# C:\Users\eoles\AppData\Local\Temp\ipykernel_14532\4048127297.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LPNS_violin['Dataset'] = 'LPNS'
# C:\Users\eoles\AppData\Local\Temp\ipykernel_14532\4048127297.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LPSC_violin['Dataset'] = 'LPSC'
