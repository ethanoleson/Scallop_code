# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cm_data = pd.read_csv('cm_data_for_plots.csv')
cm_data_modified = pd.read_csv('cm_data_for_plots_modified.csv')
cm_data_Mod_prc = pd.read_csv('cm_data_for_plots_modified_PRC.csv')

cm_data_Mod_prc
# Out:
#                      cave         feature  lithology    asfc      sa
# 0                   Omega      Solutional   Dolomite  23.350  13.710
# 1                   Omega      Mechanical   Dolomite  39.610   7.260
# 2                      J2      Solutional  Limestone  68.130  27.030
# 3                      J2      Mechanical  Limestone   2.195   1.334
# 4  Schonberg-Hohlensystem      Solutional  Limestone  28.810  12.510
# 5  Schonberg-Hohlensystem  Not Applicable  Limestone  46.020  20.350
# 6        Parks Ranch Cave      Solutional     Gyspum   8.440   4.680

# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

cm_data = pd.read_csv('cm_data_for_plots.csv')
cm_data


sns.scatterplot(data= cm_data, x= cm_data['feature'], y = cm_data['sa'], hue= cm_data['cave'],
                style= cm_data['cave'], markers={'Parks Ranch Cave': 'o', 'J2': 's', 'Schonberg-Hohlensystem': '^', 'Omega': '*'},
                palette='binary', s=100, edgecolor='black' )

plt.margins(x=0.5)
plt.xlabel('')
plt.ylabel('Sa $(\mu m)$')
plt.legend(title = '')

#plt.savefig('Sa_v_feature_by_cave.png', dpi= 300)
#plt.show()

# %%
sns.scatterplot(data= cm_data, x= cm_data['cave'], y = cm_data['sa'], hue= cm_data['feature'],
                style= cm_data['feature'], markers={'Mechanical': 'o', 'Solutional': 's', 'Unknown': 'D'},
                palette='binary', s=100, edgecolor='black' )
plt.margins(x=0.4)
plt.xticks(rotation=45)
plt.xlabel('')
plt.ylabel('Sa $(\mu m)$')
plt.legend(title = '')
plt.tight_layout()
#plt.savefig('Sa_v_cave_by_feature.png', dpi = 300)
plt.show()

# %%
sns.scatterplot(data= cm_data, x= cm_data['lithology'], y = cm_data['sa'], hue= cm_data['feature'],
                style= cm_data['cave'], markers={'Parks Ranch Cave': 'o', 'J2': 's', 'Schonberg-Hohlensystem': '^', 'Omega': '*'},
                palette='binary', s=100, edgecolor='black' )
plt.margins(x=0.5)
plt.xlabel('')
plt.ylabel('Sa $(\mu m)$')
plt.legend(title = '')

#plt.savefig('Sa_v_lith_by_feature_and_cave.png', dpi = 300)
#plt.show()

# %%
sns.scatterplot(data= cm_data, x= cm_data['lithology'], y = cm_data['sa'], hue= cm_data['feature'],
                style= cm_data['feature'], markers={'Mechanical': 'o', 'Solutional': 's'},
                palette='binary', s=100, edgecolor='black' )
plt.margins(x=0.5)
plt.xlabel('')
plt.ylabel('Sa $(\mu m)$')
plt.legend(title = '')

#plt.savefig('Sa_v_lith_by_feature.png', dpi = 300)
#plt.show()

# %%
sns.scatterplot(data= cm_data_modified, x= cm_data_modified['feature'], y = cm_data_modified['sa'], hue= cm_data['cave'],
                style= cm_data_modified['cave'], markers={ 'J2': 's', 'Schonberg-Hohlensystem': '^', 'Omega': 'o'},
                palette='binary', s=100, edgecolor='black' )
plt.margins(x=0.5)
plt.xlabel('')
plt.ylabel('Sa $(\mu m)$')
plt.legend(title = '')

#plt.savefig('Sa_v_feature_by_cave_modified.png', dpi= 300)
#plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming cm_data is a DataFrame with columns 'feature', 'sa', and 'cave'

# Scatter plot
sns.scatterplot(data=cm_data, x='feature', y='sa', hue='cave',
                style='cave', markers={'Parks Ranch Cave': 'o', 'J2': 's', 'Schonberg-Hohlensystem': '^', 'Omega': '*'},
                palette='binary', s=100, edgecolor='black')

# Get x and y positions
x_positions = cm_data['feature']
y_positions = cm_data['sa']

# Error bars
plt.errorbar(x=x_positions, y=y_positions, yerr=0.02, fmt='none', color='black')

plt.margins(x=0.5)
plt.xlabel('')
plt.ylabel('Sa $(\mu m)$')
plt.legend(title='')
plt.show()

# %%
cm_data_Mod_prc
# Out:
#                      cave         feature  lithology    asfc      sa
# 0                   Omega      Solutional   Dolomite  23.350  13.710
# 1                   Omega      Mechanical   Dolomite  39.610   7.260
# 2                      J2      Solutional  Limestone  68.130  27.030
# 3                      J2      Mechanical  Limestone   2.195   1.334
# 4  Schonberg-Hohlensystem      Solutional  Limestone  28.810  12.510
# 5  Schonberg-Hohlensystem  Not Applicable  Limestone  46.020  20.350
# 6        Parks Ranch Cave      Solutional     Gyspum   8.440   4.680

# %%
spreadsheet = cm_data_Mod_prc
markers_choice = {'Mechanical': 'o', 'Solutional': 's', 'Not Applicable': 'D'}
x_axis = 'cave'
color_by = 'feature'
marker_style = 'feature'
color_palette = 'binary'

fig, ax = plt.subplots(figsize = (6,5))

sns.scatterplot(data= spreadsheet, x= spreadsheet[x_axis], y = spreadsheet['sa'], hue= spreadsheet[color_by],
                style= spreadsheet[marker_style], markers=markers_choice,
                palette=color_palette, s=100, edgecolor='black')
ax.margins(x=0.2)
custom_xticks = [0, 1, 2, 3]  # Replace with your desired tick positions
custom_xticklabels = custom_xticklabels = ['Omega', 'J2', '$Sch \ddot{o} nberg$ \n $-H \ddot{o}hlensystem$', 'Parks Ranch \n Cave']   # Replace with your desired tick labels
ax.set_xticks(custom_xticks)
ax.set_xticklabels(custom_xticklabels)
ax.set_xlabel('')
ax.set_ylabel('Sa $(\mu m)$')
ax.legend(title = '')
plt.tight_layout()
#plt.savefig('Sa_v_cave_by_feature.png', dpi = 300)
plt.show()

# %%
def roughnessplot(df, x_axis, color_by, marker_style, color_palette, markers_choice, save = None, rotation = None):
    df = spreadsheet
    sns.scatterplot(data= spreadsheet, x= spreadsheet[x_axis], y = spreadsheet['sa'], hue= spreadsheet[color_by],
                    style= spreadsheet[marker_style], markers=markers_choice,
                    palette=color_palette, s=100, edgecolor='black')
    plt.margins(x=0.4)
    plt.xticks(rotation = rotation)
    plt.xlabel('')
    plt.ylabel('Sa $(\mu m)$')
    plt.legend(title = '')
    plt.tight_layout()
    plt.savefig(save, dpi = 300)
    plt.show()

# %%
roughnessplot(cm_data_Mod_prc, 'feature', 'cave', 'cave', 'binary', {'Parks Ranch Cave': 'o', 'J2': 's', 'Schonberg-Hohlensystem': '^', 'Omega': '*'}, save='Sa_v_feature_by_cave.png')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

spreadsheet = cm_data_Mod_prc
markers_choice = {'Mechanical': 'o', 'Solutional': 's', 'Not Applicable': 'D'}
x_axis = 'cave'
color_by = 'feature'
marker_style = 'feature'
color_palette = 'binary'

# Create a single plot
fig, ax = plt.subplots(figsize=(6, 4))

# Plot the data
sns.scatterplot(data=spreadsheet, x=spreadsheet[x_axis], y=spreadsheet['asfc'], hue=spreadsheet[color_by],
                style=spreadsheet[marker_style], markers=markers_choice,
                palette=color_palette, s=100, edgecolor='black')
ax.margins(x=0.2)
ax.set_ylabel('Asfc (dimensionless)')

# Manually set x-axis tick positions and labels
custom_xticks = [0, 1, 2, 3]  # Replace with your desired tick positions
custom_xticklabels = custom_xticklabels = ['Omega', 'J2', '$Sch \ddot{o} nberg$ \n $-H \ddot{o}hlensystem$', 'Parks Ranch \n Cave']   # Replace with your desired tick labels
ax.set_xticks(custom_xticks)
ax.set_xticklabels(custom_xticklabels)
ax.set_xlabel('')

# Create a legend
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels, loc='upper right')

# Adjust layout and save the plot

# Uncomment the line below to save the plot
plt.savefig('asfc_v_cave_by_feature.png', dpi=300)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

spreadsheet = cm_data_Mod_prc
markers_choice = {'Mechanical': 'o', 'Solutional': 's', 'Not Applicable': 'D'}
x_axis = 'cave'
color_by = 'feature'
marker_style = 'feature'
color_palette = 'binary'

# Create a figure with two vertically arranged subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# Plot for the first subplot
sns.scatterplot(ax=ax1, data=spreadsheet, x=spreadsheet[x_axis], y=spreadsheet['asfc'], hue=spreadsheet[color_by],
                style=spreadsheet[marker_style], markers=markers_choice,
                palette=color_palette, s=100, edgecolor='black')
ax1.margins(x=0.4)
ax1.tick_params(axis='x', which='both', bottom=False, top=False)  # Hide x-axis ticks for the first subplot
ax1.set_ylabel('Asfc (dimensionless)')
ax1.legend(title='')

# Plot for the second subplot
sns.scatterplot(ax=ax2, data=spreadsheet, x=spreadsheet[x_axis], y=spreadsheet['asfc'], hue=spreadsheet[color_by],
                style=spreadsheet[marker_style], markers=markers_choice,
                palette=color_palette, s=100, edgecolor='black')
ax2.margins(x=0.4)
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
ax2.set_xlabel('')
ax2.set_ylabel('Asfc (dimensionless)')
ax2.legend()

# Adjust layout and save the plot

# Uncomment the line below to save the plot
# plt.savefig('Sa_v_cave_by_feature_subplots.png', dpi=300)

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

spreadsheet = cm_data_Mod_prc
markers_choice = {'Mechanical': 'o', 'Solutional': 's', 'Not Applicable': 'D'}
x_axis = 'cave'
color_by = 'feature'
marker_style = 'feature'
color_palette = 'binary'

# Create a figure with two vertically arranged subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# Plot for the first subplot
sns.scatterplot(ax=ax1, data=spreadsheet, x=spreadsheet['cave'], y=spreadsheet['sa'], hue=spreadsheet[color_by],
                style=spreadsheet[marker_style], markers=markers_choice,
                palette=color_palette, s=100, edgecolor='black')
ax1.margins(x=0.4)
ax1.tick_params(axis='x', which='both', bottom=False, top=False)  # Hide x-axis ticks for the first subplot
ax1.set_ylabel('Sa ($\mu m$)')
ax1.legend('')

# Plot for the second subplot
sns.scatterplot(ax=ax2, data=spreadsheet, x=spreadsheet[x_axis], y=spreadsheet['asfc'], hue=spreadsheet[color_by],
                style=spreadsheet[marker_style], markers=markers_choice,
                palette=color_palette, s=100, edgecolor='black')
ax2.margins(x=0.4)
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
ax2.set_xlabel('')
ax2.set_ylabel('Asfc (dimensionless)')
ax2.legend('')

# Create a legend outside the subplots
handles, labels = ax2.get_legend_handles_labels()
fig.legend(handles, labels, loc='lower left', title='')

# Adjust layout and save the plot

# Uncomment the line below to save the plot
# plt.savefig('Sa_v_cave_by_feature_subplots.png', dpi=300)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

spreadsheet = cm_data_Mod_prc
markers_choice = {'Mechanical': 'o', 'Solutional': 's', 'Not Applicable': 'D'}
x_axis = 'cave'
color_by = 'feature'
marker_style = 'feature'
color_palette = 'binary'

# Create a figure with two vertically arranged subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6), sharex=True)

# Plot for the first subplot
sns.scatterplot(ax=ax1, data=spreadsheet, x=spreadsheet[x_axis], y=spreadsheet['sa'], hue=spreadsheet[color_by],
                style=spreadsheet[marker_style], markers=markers_choice,
                palette=color_palette, s=100, edgecolor='black')
ax1.margins(x=0.2)
ax1.tick_params(axis='x', which='both', bottom=False, top=False)  # Hide x-axis ticks for the first subplot
ax1.set_ylabel('Sa $(\mu m)$')
ax1.legend('')

# Plot for the second subplot
sns.scatterplot(ax=ax2, data=spreadsheet, x=spreadsheet[x_axis], y=spreadsheet['asfc'], hue=spreadsheet[color_by],
                style=spreadsheet[marker_style], markers=markers_choice,
                palette=color_palette, s=100, edgecolor='black')
ax2.margins(x=0.2)
ax2.set_xlabel('')
ax2.set_ylabel('Asfc (dimensionless)')
ax2.legend('')

# Manually set x-axis tick positions and labels for the second subplot
custom_xticks = [0,1, 2, 3]  # Replace with your desired tick positions
custom_xticklabels = ['Omega', 'J2', '$Sch \ddot{o} nberg$ \n $-H \ddot{o}hlensystem$', 'Parks Ranch \n Cave']   # Replace with your desired tick labels
ax2.set_xticks(custom_xticks)
ax2.set_xticklabels(custom_xticklabels)

# Create a legend outside the subplots
handles, labels = ax2.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', title= '', ncol = 3,  bbox_to_anchor=(0.5,-0.01))

# Adjust layout and save the plot

# Uncomment the line below to save the plot
plt.savefig('Asfc and Sa_v_cave_by_feature_subplots.png', dpi=300)

plt.tight_layout()
plt.show()
